# %% [markdown]
# # Etude d'un jeu de données : caractéristiques de 3 espèces de faucons
#
# Nous avons trouvé à cette [adresse](https://www.picostat.com/dataset/r-dataset-package-stat2data-hawks?fbclid=IwAR3sSZpCuSP1uZoiSmoZQRoNLA69l-pBcldyyub-9DQjYI92uaq7B4WDUK4) un dataset d'étude de faucons. On y retrouve 3 espèces avec leurs caractéristiques. Notre objectif sera d'étudier l'influence de chaque caractéristiques par rapport à l'espèce de faucon ainsi que la corrélation de certaines de ces caractéristiques.
#
# ## Voici les principales caractéristiques de notre dataset :
#
# * **Species** : CH=Cooper's, RT=Red-tailed, SS=Sharp-Shinned
#
# <img style='height:250px' src="https://i.pinimg.com/originals/e3/7b/9a/e37b9afde74ed5ac7fa52e74afbe036b.jpg"> <img style='height:250px' src="https://upload.wikimedia.org/wikipedia/commons/d/d3/Red-tailed_hawk_in_flight_end-of-day_little_bay_%2826112460594%29.jpg"> <img style='height:250px' src="https://i.pinimg.com/originals/dd/e9/18/dde918cfb76e9d1b818ffe821725a2d0.jpg">
#
# * **Age** : A=Adult or I=Imature
# * **Sex** : F=Female or M=Male
# * **Wing** : Length (in mm) of primary wing feather from tip to wrist it attaches to
# * **Weight** : Body weight (in gm)
# * **Culmen** : Length (in mm) of the upper bill from the tip to where it bumps into the fleshy part of the bird
# * **Hallux** : Length (in mm) of the killing talon
# * **Tail** : Measurement (in mm) related to the length of the tail (invented at the MacBride Raptor Center)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://www.picostat.com/system/files/datasets/dataset-48225.csv')
data
# Out:
#      Month  Day  Year CaptureTime ReleaseTime  BandNumber Species Age  Sex  \
# 0        9   19  1992       13:30         NaN   877-76317      RT   I  NaN
# 1        9   22  1992       10:30               877-76318      RT   I  NaN
# 2        9   23  1992       12:45               877-76319      RT   I  NaN
# 3        9   23  1992       10:50               745-49508      CH   I    F
# 4        9   27  1992       11:15              1253-98801      SS   I    F
# ..     ...  ...   ...         ...         ...         ...     ...  ..  ...
# 903     11   18  2003       14:44              1177-04777      RT   I  NaN
# 904     11   19  2003       10:18               803-05985      SS   I    F
# 905     11   19  2003       12:02              1807-53145      RT   I  NaN
# 906     11   20  2003        9:56              1177-04778      RT   I  NaN
# 907     11   20  2003       13:30              1207-53145      RT   A  NaN
#
# ...

# %% [markdown]
# ## Nettoyage du dataset
#
# On va ne conserver nottament que les données chiffrés que l'on peut exploiter dans le dataset :

# %%
cols = ['Species', 'Age', 'Sex', 'Wing', 'Weight', 'Culmen', 'Hallux', 'Tail']
data_new = data[cols]
data_new
# Out:
#     Species Age  Sex   Wing  Weight  Culmen  Hallux  Tail
# 0        RT   I  NaN  385.0   920.0    25.7    30.1   219
# 1        RT   I  NaN  376.0   930.0     NaN     NaN   221
# 2        RT   I  NaN  381.0   990.0    26.7    31.3   235
# 3        CH   I    F  265.0   470.0    18.7    23.5   220
# 4        SS   I    F  205.0   170.0    12.5    14.3   157
# ..      ...  ..  ...    ...     ...     ...     ...   ...
# 903      RT   I  NaN  380.0  1525.0    26.0    27.6   224
# 904      SS   I    F  190.0   175.0    12.7    15.4   150
# 905      RT   I  NaN  360.0   790.0    21.9    27.6   211
# 906      RT   I  NaN  369.0   860.0    25.2    28.0   207
# 907      RT   A  NaN  199.0  1290.0    28.7    32.1   222
#
# [908 rows x 8 columns]

# %%
data_new.describe()
# Out:
#              Wing       Weight      Culmen      Hallux        Tail
# count  907.000000   898.000000  901.000000  902.000000  908.000000
# mean   315.637486   772.080178   21.801498   26.410865  198.831498
# std     95.277591   462.311760    7.284175   17.734704   36.824403
# min     37.200000    56.000000    8.600000    9.500000  119.000000
# 25%    202.000000   185.000000   12.800000   15.100000  160.000000
# 50%    370.000000   970.000000   25.500000   29.400000  214.000000
# 75%    390.000000  1120.000000   27.300000   31.400000  225.000000
# max    480.000000  2030.000000   39.200000  341.400000  288.000000

# %% [markdown]
# ## Etude des caractéristiques & corrélations
#
# On affiche les caractéristiques propres aux différentes espèces :

# %%
for name in data_new['Species'].unique():
    print("Species:", name)
    display(data_new[data_new['Species'] == name].describe())
# Out:
# Species: RT
#             Wing      Weight      Culmen      Hallux        Tail
# count  577.00000   572.00000  573.000000  574.000000  577.000000
# mean   383.30364  1094.43007   26.965969   31.993990  222.149047
# std     31.48714   189.21025    2.050474   17.666668   14.510962
# min     37.20000   101.00000   15.700000   10.300000  122.000000
# 25%    372.00000   980.00000   25.800000   29.600000  214.000000
# 50%    384.00000  1070.00000   26.800000   30.800000  221.000000
# 75%    399.00000  1210.00000   28.100000   32.200000  230.000000
# max    480.00000  2030.00000   39.200000  341.400000  288.000000
# Species: CH
#              Wing       Weight     Culmen     Hallux        Tail
# count   69.000000    70.000000  70.000000  70.000000   70.000000
# mean   244.144928   420.485714  17.565714  22.818571  200.914286
# std     32.132664   162.031643   2.392857   5.416963   17.880232
# min    145.000000    56.000000  12.200000  13.800000  157.000000
# ...

# %% [markdown]
# ### Affichage des caractéristiques par espèce
#
# Un peu de **DataViz** sur nos espèces

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
sns.set()
current_palette= sns.color_palette()
colors = {i: current_palette[i] for i in range(3)}

sns.palplot(current_palette[:3])
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 20)) 

sns.boxplot(x='Species',
            y= 'Wing',
            data=data_new,              
            ax=ax[0,0])

sns.boxplot(x='Species',
            y= 'Weight',
            data=data_new,              
            ax=ax[1,0])

sns.boxplot(x='Species',
            y= 'Culmen',
            data=data_new,              
            ax=ax[0,1])

sns.boxplot(x='Species',
            y= 'Tail',
            data=data_new,              
            ax=ax[1,1])

plt.show()

# %% [markdown]
# ### Affichage de chaque caractéristique en fonction de chacune des autres caractéristiques
#
# On colorise chaque espèce de manière différente.

# %%
sns.pairplot(data_new, hue="Species", markers=["o", "s", "D"])
plt.show()

# %% [markdown]
# ### Corrélations des caractéristiques, sur l'ensemble des espèces

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data_new.corr(), 
            annot=True, 
            vmin=0, 
            vmax=1,
            ax=ax,
            cmap="YlGnBu")
plt.show()

# %% [markdown]
# On remarque qu'**Hallux** est trés peu corrélé avec les autres données.

# %% [markdown]
# ### Corrélation des caractéristiques, par espèce

# %%
data_new.groupby('Species').corr()
# Out:
#                     Wing    Weight    Culmen    Hallux      Tail
# Species
# CH      Wing    1.000000  0.547826  0.653409  0.221724  0.541650
#         Weight  0.547826  1.000000  0.660705  0.426994  0.561783
#         Culmen  0.653409  0.660705  1.000000  0.233066  0.533846
#         Hallux  0.221724  0.426994  0.233066  1.000000  0.267886
#         Tail    0.541650  0.561783  0.533846  0.267886  1.000000
# RT      Wing    1.000000  0.336467  0.430485  0.100771  0.320376
#         Weight  0.336467  1.000000  0.543931  0.098991  0.256490
#         Culmen  0.430485  0.543931  1.000000  0.134772  0.351333
#         Hallux  0.100771  0.098991  0.134772  1.000000  0.081847
#         Tail    0.320376  0.256490  0.351333  0.081847  1.000000
# SS      Wing    1.000000  0.862904  0.831481  0.058161  0.871766
#         Weight  0.862904  1.000000  0.862206  0.021954  0.763939
#         Culmen  0.831481  0.862206  1.000000  0.053842  0.777119
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data_new.groupby('Species').corr(), annot=True)
plt.show()

# %% [markdown]
# ## Catégorisation des données.
#
# Dans cette partie nous allons essayer de retrouver les différentes espèces de faucons à partir du set de données.
#
# Pour cela nous allons d'abord nettoyer un peu plus notre dataset.
#
# Nous allons remplacer les **NaN** dans notre dataset par la **moyenne** de la colonne associée.

# %%
moyennes = data_new.loc[:,:].mean()
moyennes
# Out:
# Wing      315.637486
# Weight    772.080178
# Culmen     21.801498
# Hallux     26.410865
# Tail      198.831498
# dtype: float64

# %%
cols_categ =  ['Wing', 'Weight', 'Culmen', 'Hallux', 'Tail']
data_categ = data_new.fillna(moyennes)[cols_categ]
data_categ
# Out:
#       Wing  Weight     Culmen     Hallux  Tail
# 0    385.0   920.0  25.700000  30.100000   219
# 1    376.0   930.0  21.801498  26.410865   221
# 2    381.0   990.0  26.700000  31.300000   235
# 3    265.0   470.0  18.700000  23.500000   220
# 4    205.0   170.0  12.500000  14.300000   157
# ..     ...     ...        ...        ...   ...
# 903  380.0  1525.0  26.000000  27.600000   224
# 904  190.0   175.0  12.700000  15.400000   150
# 905  360.0   790.0  21.900000  27.600000   211
# 906  369.0   860.0  25.200000  28.000000   207
# 907  199.0  1290.0  28.700000  32.100000   222
#
# [908 rows x 5 columns]

# %% [markdown]
# ### La méthode des Kmeans
#
# La méthode la plus simple que nous avons vu en cours pour catégoriser des données est la méthode des **Kmeans**. On va utiliser la fonction KMeans de sklearn pour ça.

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# #### Combien de clusters ?
#
# Pour déterminer le nombre de clusters optimal nous allons étudier les différentes **inerties** générées par un nombre de clusters entre 1 et 20.

# %%
inertie = []

for nb in range(1, 20):
    kmeans = KMeans(n_clusters=nb,
                    n_init=10, 
                    max_iter=300).fit(data_categ)
    inertie.append(kmeans.inertia_)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

sns.lineplot(x=list(range(1, len(inertie) + 1)), 
             y=inertie,
             ax=ax)
ax.set_title('Inerties / Nombres de clusteurs')
plt.show()

# %% [markdown]
# **3** clusters (comme le nombre d'espèces différentes du dataset !) semble être le plus optimal.

# %%
n_clusters = 3

# %% [markdown]
# #### Quelques fonctions utiles pour éviter de réécrire ces lignes encore et encore :
#
# Une fois les clusters déterminés on les ajoute au DataFrame avec cette fonction et on en profite pour afficher un pairplot des 5 colonnes colorisé en fonction des clusters.

# %%
def add_clusters_and_pairplot(clusters):
    data = data_categ.copy()
    data['Clusters'] = clusters
    sns.pairplot(data, hue='Clusters', palette=colors)
    plt.show()
    return data

# %% [markdown]
# Cette fonction nous permet de comparer nos résultats de catégorisation avec les différentes espèces présentent dans le dataset.

# %%
def compare_clusters_and_species(data_with_clusters):
    data_with_clusters['Species'] = data_new['Species']
    species = data_with_clusters.Species.unique()

    categs = np.zeros((3, 3))

    for i in range(len(data_with_clusters)):
        faucon = data_with_clusters.loc[i]

        for j in range(len(species)):
            if (faucon.Species == species[j]):
                categs[faucon.Clusters][j] += 1

    return pd.DataFrame(categs, index = ['Cluster 0', 'Cluster 1', 'Cluster 2'], columns = species)

# %% [markdown]
# #### Avec 3 clusters :

# %%
kmeans = KMeans(n_clusters=n_clusters,
                    n_init=10, 
                    max_iter=300).fit(data_categ)
clusters_kmeans = kmeans.predict(data_categ)

# %%
data_kmeans = add_clusters_and_pairplot(clusters_kmeans)

# %% [markdown]
# Ouch, on dirait que nos Kmeans n'ont pas reussit à catégoriser les données par espèces comme vues plus tôt... \
# Voyons voir la corrélation entre espèces et clusters.

# %%
df_kmeans = compare_clusters_and_species(data_kmeans)
df_kmeans
# Out:
#               RT    CH     SS
# Cluster 0  357.0   4.0    6.0
# Cluster 1    6.0  66.0  255.0
# Cluster 2  214.0   0.0    0.0

# %% [markdown]
# On remarque que la catégorisation par espèces n'est un pas un franc succés :
# CH=Cooper's, RT=Red-tailed, SS=Sharp-Shinned
# * L'espèce **Red-tailed** (RT) a été séparé entre le cluster **0** et **2**.
# * L'espèce **Cooper's** (CH) semble avoir été catégorisé dans le cluster **1** mais il s'agit aussi du cluster catégorisant aussi l'espèce **Sharp-Shinned** (SS).
# * L'espèce **Sharp-Shinned** (SS) a été presque à 100% catégorisée dans le cluster **1** mais comme dit si-dessus il s'agit aussi du cluster contenant aussi l'espèce **Cooper's** (CH).

# %% [markdown]
# <img style='height:350px' src='https://lh3.googleusercontent.com/proxy/aMDFyWp6u5hz0yCODuqy2xBiKkwq6p35f-61OumvtzUb5tL3_7dUdCP-FoZVp970kH92b_ibAxGRHQDTZ2SrHhWjyNIOad3FUjEq70NLIR1OkoRd4uTjU0rUPS8A6ate7XD1lRmKaaCmvPr8903-AIaZ8Ir8U_rrsKc'>

# %% [markdown]
# Aprés quelques recherches sur le site de [**Sklearn**](https://scikit-learn.org/stable/modules/clustering.html?fbclid=IwAR3KnNUOjsnNLAIPQtRiy9xWedv8kyIcqpWSPQJw9cHSF0mRj6npvoYJ-QM) nous allons tester d'autres méthodes de clustering proposées par cette librairie :
# * **AgglomerativeClustering** : Une méthode de clustering hiérarchique, par défaut on utilise le type *Ward*.
# * **GaussianMixture** : Une méthode d'approximation de clusters par des densités *Gaussiennes*.

# %% [markdown]
# ### AgglomerativeClustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
agg = AgglomerativeClustering(n_clusters=n_clusters).fit(data_categ)
clusters_agg = agg.labels_

# %%
data_agg = add_clusters_and_pairplot(clusters_agg)

# %%
df_agg = compare_clusters_and_species(data_agg)
df_agg
# Out:
#               RT    CH     SS
# Cluster 0    6.0  67.0  255.0
# Cluster 1  400.0   3.0    6.0
# Cluster 2  171.0   0.0    0.0

# %% [markdown]
# Hélas on retrouve les mêmes problèmes qu'avec la méthode des Kmeans. L'espèce **RT** est séparée entre 2 clusters et les espèces **CH** et **SS** sont rassemnlées dans le même cluster.

# %% [markdown]
# ### GaussianMixture

# %%
from sklearn.mixture import GaussianMixture

# %%
gm = GaussianMixture(n_components=n_clusters).fit(data_categ)
clusters_gm = gm.predict(data_categ)

# %%
data_gm = add_clusters_and_pairplot(clusters_gm)

# %%
df_gm = compare_clusters_and_species(data_gm)
df_gm
# Out:
#               RT    CH     SS
# Cluster 0    0.0  47.0  238.0
# Cluster 1   41.0  23.0   23.0
# Cluster 2  536.0   0.0    0.0

# %% [markdown]
# On remarque ici que **RT** est mieux clusterisée mais **CH** et **SS** le restent assez mal.
#
# Les différentes méthodes échouent à clusteriser en espèce, n'y a-t-il pas un moyen de traiter le dataset pour augmenter les performances ?

# %% [markdown]
# ## ACP : analyse en composantes principales

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Centrer et réduire les données

# %%
scaler = StandardScaler()

data_acp = pd.DataFrame(scaler.fit_transform(data_categ), columns=data_categ.columns)

data_acp
# Out:
#          Wing    Weight        Culmen        Hallux      Tail
# 0    0.728808  0.321913  5.375749e-01  2.088244e-01  0.547996
# 1    0.634243  0.343675 -1.469680e-15 -2.011022e-16  0.602338
# 2    0.686779  0.474251  6.754677e-01  2.767506e-01  0.982730
# 3   -0.532059 -0.657406 -4.276740e-01 -1.647702e-01  0.575167
# 4   -1.162493 -1.310286 -1.282609e+00 -6.855383e-01 -1.136598
# ..        ...       ...           ...           ...       ...
# 903  0.676271  1.638553  5.789428e-01  6.731128e-02  0.683850
# 904 -1.320101 -1.299405 -1.255030e+00 -6.232726e-01 -1.326794
# 905  0.466127  0.038998  1.358266e-02  6.731128e-02  0.330629
# 906  0.560692  0.191337  4.686286e-01  8.995337e-02  0.221945
# 907 -1.225536  1.127131  9.512531e-01  3.220348e-01  0.629508
#
# [908 rows x 5 columns]

# %% [markdown]
# ### On applique l'ACP

# %%
pca = PCA() 
pca.fit(data_acp)
pca.explained_variance_ratio_
# Out:
# array([0.80018637, 0.15086771, 0.02763089, 0.01321539, 0.00809964])

# %% [markdown]
# **80%** de l'information est contenue par l'axe **0**. \
# On transpose cette matrice pour **projeter** nos données sur **cet axe** :

# %%
pca_stranspose = np.transpose(pca.components_)
print(pca_stranspose[:,0])
data_proj = pd.DataFrame(data_acp.dot(pca_stranspose[:,0]))
data_proj
# Out:
# [0.4843712  0.47963319 0.48838789 0.27513784 0.47022652]
#             0
# 0    1.085096
# 1    0.755282
# 2    1.428263
# 3   -0.556775
# 4   -2.541022
# ..        ...
# 903  1.736304
# 904 -2.670978
# 905  0.425107
# 906  0.721341
# 907  0.796191
#
# [908 rows x 1 columns]

# %% [markdown]
# On obtient un vecteur à **une seule dimension** qui représente nos données.

# %%
sns.displot(data_proj, kde = True)
plt.show()

# %% [markdown]
# ### On catégorise l'APC
#
# Une fois l'APC appliquée à nos données on peut rééssayer de les catégoriser avec les méthodes précédentes.
#
# #### Avec les Kmeans

# %%
pca_kmeans = KMeans(n_clusters=n_clusters,
                    n_init=10, 
                    max_iter=300).fit(data_proj)
clusters_pca_kmeans = pca_kmeans.predict(data_proj)

# %%
data_pca_kmeans = add_clusters_and_pairplot(clusters_pca_kmeans)
df_pca_kmeans = compare_clusters_and_species(data_pca_kmeans)
df_pca_kmeans
# Out:
#               RT    CH     SS
# Cluster 0    0.0   3.0  250.0
# Cluster 1  573.0   2.0    1.0
# Cluster 2    4.0  65.0   10.0

# %% [markdown]
# On obseve une nette améliroration de la catégorisation en espèces différentes ! \
# Seulement **20** faucons soit **2%** du dataset mal catégorisés !
# ##### Et avec les 2 premiers vecteurs ?

# %%
data_proj_2_axes = pd.DataFrame(data_acp.dot(pca_stranspose[:,0:2]))
data_proj_2_axes
# Out:
#             0         1
# 0    1.085096 -0.093685
# 1    0.755282 -0.221747
# 2    1.428263 -0.124352
# 3   -0.556775 -0.022225
# 4   -2.541022  0.013153
# ..        ...       ...
# 903  1.736304 -0.427389
# 904 -2.670978  0.117209
# 905  0.425107 -0.054656
# 906  0.721341 -0.110680
# 907  0.796191  0.109261
#
# [908 rows x 2 columns]

# %%
pca_kmeans = KMeans(n_clusters=n_clusters,
                    n_init=10, 
                    max_iter=300).fit(data_proj_2_axes)
clusters_pca_kmeans = pca_kmeans.predict(data_proj_2_axes)
data_pca_kmeans = add_clusters_and_pairplot(clusters_pca_kmeans)
df_pca_kmeans = compare_clusters_and_species(data_pca_kmeans)
df_pca_kmeans
# Out:
#               RT    CH     SS
# Cluster 0    3.0  51.0  260.0
# Cluster 1  572.0  19.0    1.0
# Cluster 2    2.0   0.0    0.0

# %% [markdown]
# Oups... On trouve **2** points aberrants qui nous vident le dernier cluster...

# %%
data_pca_kmeans[data_pca_kmeans.Clusters == 2]
# Out:
#      Wing  Weight  Culmen  Hallux  Tail  Clusters Species
# 90  410.0  1210.0    27.5   308.0   227         2      RT
# 95  418.0  1180.0    30.1   341.4   235         2      RT

# %%
data_pca_kmeans.describe()
# Out:
#              Wing       Weight      Culmen      Hallux        Tail    Clusters
# count  908.000000   908.000000  908.000000  908.000000  908.000000  908.000000
# mean   315.637486   772.080178   21.801498   26.410865  198.831498    0.656388
# std     95.225053   459.756119    7.256012   17.675947   36.824403    0.479793
# min     37.200000    56.000000    8.600000    9.500000  119.000000    0.000000
# 25%    202.000000   186.750000   12.800000   15.175000  160.000000    0.000000
# 50%    370.000000   967.000000   25.500000   29.400000  214.000000    1.000000
# 75%    390.000000  1120.000000   27.300000   31.400000  225.000000    1.000000
# max    480.000000  2030.000000   39.200000  341.400000  288.000000    2.000000

# %%
def add_clusters_and_pairplot_and_drop(clusters, columns_to_drop):
    data = data_categ.drop(columns_to_drop).copy()
    data['Clusters'] = clusters
    sns.pairplot(data, hue='Clusters', palette=colors)
    plt.show()
    return data

# %%
def compare_clusters_and_species_and_drop(data_with_clusters, columns_to_drop):
    data_with_clusters['Species'] = data_new.drop(columns_to_drop)['Species']
    species = data_with_clusters.Species.unique()

    categs = np.zeros((3, 3))

    for i in range(len(data_with_clusters)):
        if i not in columns_to_drop:
            faucon = data_with_clusters.loc[i]

            for j in range(len(species)):
                if (faucon.Species == species[j]):
                    categs[faucon.Clusters][j] += 1

    return pd.DataFrame(categs, index = ['Cluster 0', 'Cluster 1', 'Cluster 2'], columns = species)

# %%
data_proj_2_axes_2 = data_proj_2_axes.drop([90, 95])
pca_kmeans = KMeans(n_clusters=n_clusters,
                    n_init=10, 
                    max_iter=300).fit(data_proj_2_axes_2)
clusters_pca_kmeans = pca_kmeans.predict(data_proj_2_axes_2)
data_pca_kmeans = add_clusters_and_pairplot_and_drop(clusters_pca_kmeans, [90, 95])
df_pca_kmeans = compare_clusters_and_species_and_drop(data_pca_kmeans, [90, 95])
df_pca_kmeans
# Out:
#               RT    CH     SS
# Cluster 0    4.0  65.0   10.0
# Cluster 1  569.0   2.0    1.0
# Cluster 2    0.0   3.0  250.0

# %% [markdown]
# On obtient le même résultat, **20** faucons mal catégorisés.

# %% [markdown]
# #### Avec l'AgglomerativeClustering

# %%
pca_agg = AgglomerativeClustering(n_clusters=n_clusters).fit(data_proj)
clusters_pca_agg = pca_agg.labels_

# %%
data_pca_agg = add_clusters_and_pairplot(clusters_pca_agg)
df_pca_agg = compare_clusters_and_species(data_pca_agg)
df_pca_agg
# Out:
#               RT    CH     SS
# Cluster 0  573.0   2.0    1.0
# Cluster 1    0.0   3.0  250.0
# Cluster 2    4.0  65.0   10.0

# %% [markdown]
# Même résultat

# %% [markdown]
# #### Avec la GaussianMixture

# %%
gm = GaussianMixture(n_components=n_clusters).fit(data_proj)
clusters_gm = gm.predict(data_proj)

# %%
data_gm = add_clusters_and_pairplot(clusters_gm)
df_gm = compare_clusters_and_species(data_gm)
df_gm
# Out:
#               RT    CH     SS
# Cluster 0    0.0   3.0  250.0
# Cluster 1   13.0  66.0   10.0
# Cluster 2  564.0   1.0    1.0

# %% [markdown]
# Quasiment la même chose, **21** faucons mal catégorisés

# %%
pd.DataFrame(pca_stranspose[:,0], index=data_categ.columns)
# Out:
#                0
# Wing    0.484371
# Weight  0.479633
# Culmen  0.488388
# Hallux  0.275138
# Tail    0.470227

# %% [markdown]
#  Ce vecteur nous permet donc de mieux catégoriser les faucons par espèce. Il décrit l'importance de chaque caractéristique.
#
#  <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSaVThtHKMYonhNzOTLOzMt-dfxksEVvJUKWA&usqp=CAU'>
